# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
import numpy as np 
from sklearn.preprocessing import StandardScaler
from kmodes.kprototypes import KPrototypes

# %%
data = pd.read_csv("df_par_id.csv")

# %%
data
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 0               0  0000366f3b9a7992bf8c76cfdf3221e2          12.00
# 1               1  0000b849f77a49e4a4ce2b2a4ca5be3f           8.29
# 2               2  0000f46a3911fa3c0805444483337064          17.22
# 3               3  0000f6ccb0745a6a4b88665a16c9f078          17.63
# 4               4  0004aac84e0df4da2b147fca70cf8255          16.89
# ...           ...                               ...            ...
# 94716       94716  fffcf5a5ff07b0908bd4e2dbc735a684         248.71
# 94717       94717  fffea47cd6d3cc0a88bd621562a9d061          19.69
# 94718       94718  ffff371b4d645b6ecea244b27531430a          22.56
# 94719       94719  ffff5962728ec6157033ef9805bacc48          18.69
# 94720       94720  ffffd2657e2aad2907e67c3e9daecbeb          14.57
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 0               5.0         1.0   129.90        4.0            4.0        9.0
# ...

# %%
data.customer_unique_id.nunique()
# Out:
# 94721

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'customer_unique_id', 'freight_value', 'review_score',
#        'score_freq', 'price_y', 'score_rec', 'score_montant', 'score_rfm',
#        'order_purchase_timestamp', 'customer_city', 'order_id', 'product_id',
#        'seller_id', 'categorie_regroupee'],
#       dtype='object')

# %%
data
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 0               0  0000366f3b9a7992bf8c76cfdf3221e2          12.00
# 1               1  0000b849f77a49e4a4ce2b2a4ca5be3f           8.29
# 2               2  0000f46a3911fa3c0805444483337064          17.22
# 3               3  0000f6ccb0745a6a4b88665a16c9f078          17.63
# 4               4  0004aac84e0df4da2b147fca70cf8255          16.89
# ...           ...                               ...            ...
# 94716       94716  fffcf5a5ff07b0908bd4e2dbc735a684         248.71
# 94717       94717  fffea47cd6d3cc0a88bd621562a9d061          19.69
# 94718       94718  ffff371b4d645b6ecea244b27531430a          22.56
# 94719       94719  ffff5962728ec6157033ef9805bacc48          18.69
# 94720       94720  ffffd2657e2aad2907e67c3e9daecbeb          14.57
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 0               5.0         1.0   129.90        4.0            4.0        9.0
# ...

# %% [markdown]
# ## classer DF d'apres order_purchased_timestamp

# %%
data
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 0               0  0000366f3b9a7992bf8c76cfdf3221e2          12.00
# 1               1  0000b849f77a49e4a4ce2b2a4ca5be3f           8.29
# 2               2  0000f46a3911fa3c0805444483337064          17.22
# 3               3  0000f6ccb0745a6a4b88665a16c9f078          17.63
# 4               4  0004aac84e0df4da2b147fca70cf8255          16.89
# ...           ...                               ...            ...
# 94716       94716  fffcf5a5ff07b0908bd4e2dbc735a684         248.71
# 94717       94717  fffea47cd6d3cc0a88bd621562a9d061          19.69
# 94718       94718  ffff371b4d645b6ecea244b27531430a          22.56
# 94719       94719  ffff5962728ec6157033ef9805bacc48          18.69
# 94720       94720  ffffd2657e2aad2907e67c3e9daecbeb          14.57
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 0               5.0         1.0   129.90        4.0            4.0        9.0
# ...

# %%
data["order_purchase_timestamp"] = data["order_purchase_timestamp"].str[:10]

# %%
data['order_purchase_timestamp'].dtypes
# Out:
# dtype('O')

# %%
data['order_purchase_timestamp'] = pd.to_datetime(data['order_purchase_timestamp'], errors='coerce')

# %%
data = data[data['order_purchase_timestamp'].notna()]

# %%
data  = data.sort_values('order_purchase_timestamp')

# %%
data = data_sorted

# %%
data_sorted
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 12618       12618  21dbe8eabd00b34492a939c540e2b1a7           7.39
# 65178       65178  afbcfd0b9c5233e7ccc73428526fbb52           7.90
# 67822       67822  b701bebbdf478f5500348f03aff62121           8.33
# 4647         4647  0c6d7218d5f3fa14514fd29865269993           8.45
# 67034       67034  b4dcade04bc548b7e3b0243c801f8c26           7.95
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
data_2016 = data[data['order_purchase_timestamp'].dt.year == 2016]
data_2016 = data_2016.sort_values('order_purchase_timestamp')

# %%
data_2016 = data_2016.dropna()

# %%
data_2016_2017 = data[data['order_purchase_timestamp'].dt.year == (2016 or 2017)]
data_2016_2017 = data.sort_values('order_purchase_timestamp')

# %%
data_2016_2017 = data_2016_2017.dropna()

# %%
data_2016_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92791 entries, 68118 to 67034
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                92791 non-null  int64
#  1   customer_unique_id        92791 non-null  object
#  2   freight_value             92791 non-null  float64
#  3   review_score              92791 non-null  float64
#  4   score_freq                92791 non-null  float64
#  5   price_y                   92791 non-null  float64
#  6   score_rec                 92791 non-null  float64
#  7   score_montant             92791 non-null  float64
#  8   score_rfm                 92791 non-null  float64
#  9   order_purchase_timestamp  92791 non-null  datetime64[ns]
#  10  customer_city             92791 non-null  object
#  11  order_id                  92791 non-null  object
#  12  product_id                92791 non-null  object
# ...

# %%
data_pourcent
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 8943         8943  17eb2dcf3b6c44be06f2212d1cb555cc          17.42
# 16557       16557  2c97c0c366a208653fe4cd1b80c7775a          18.98
# 60178       60178  a27b4653c3c45bbb1b1c9f12c91e6c9f          29.71
# 7717         7717  14967f4bec96864de5c5e2ce63b80bc2          43.29
# 68194       68194  b8043dc7e600706b2f7aa3b8e360f5a4          37.48
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
data_2016_2017
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 34329       34329  5c58de6fb80e93396e2f35642666b693          46.48
# 45274       45274  7a22d14aa3c3599238509ddca4b93b01           9.20
# 4647         4647  0c6d7218d5f3fa14514fd29865269993           8.45
# 47461       47461  7febafa06d9d8f232a900a2937f04338          15.39
# 67034       67034  b4dcade04bc548b7e3b0243c801f8c26           7.95
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
data
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 12618       12618  21dbe8eabd00b34492a939c540e2b1a7           7.39
# 65178       65178  afbcfd0b9c5233e7ccc73428526fbb52           7.90
# 67822       67822  b701bebbdf478f5500348f03aff62121           8.33
# 4647         4647  0c6d7218d5f3fa14514fd29865269993           8.45
# 67034       67034  b4dcade04bc548b7e3b0243c801f8c26           7.95
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
data_2016_2017
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 34329       34329  5c58de6fb80e93396e2f35642666b693          46.48
# 45274       45274  7a22d14aa3c3599238509ddca4b93b01           9.20
# 4647         4647  0c6d7218d5f3fa14514fd29865269993           8.45
# 47461       47461  7febafa06d9d8f232a900a2937f04338          15.39
# 67034       67034  b4dcade04bc548b7e3b0243c801f8c26           7.95
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
n = int(len(data_sorted) * 0.9) # calculate the index of the last row to keep
data_pourcent = data_sorted.iloc[:n, :] # create a new DataFrame with the first 90% of the rows

# %%
data_pourcent = data_pourcent.dropna()
data_pourcent = data_pourcent.sort_values('order_purchase_timestamp')

# %%
data_pourcent
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 8943         8943  17eb2dcf3b6c44be06f2212d1cb555cc          17.42
# 16557       16557  2c97c0c366a208653fe4cd1b80c7775a          18.98
# 60178       60178  a27b4653c3c45bbb1b1c9f12c91e6c9f          29.71
# 7717         7717  14967f4bec96864de5c5e2ce63b80bc2          43.29
# 68194       68194  b8043dc7e600706b2f7aa3b8e360f5a4          37.48
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
n
# Out:
# 83511

# %%
data.order_purchase_timestamp.unique()
# Out:
# array(['2016-09-04T00:00:00.000000000', '2016-09-05T00:00:00.000000000',
#        '2016-09-15T00:00:00.000000000', '2016-10-02T00:00:00.000000000',
#        '2016-10-03T00:00:00.000000000', '2016-10-04T00:00:00.000000000',
#        '2016-10-05T00:00:00.000000000', '2016-10-06T00:00:00.000000000',
#        '2016-10-07T00:00:00.000000000', '2016-10-08T00:00:00.000000000',
#        '2016-10-09T00:00:00.000000000', '2016-10-10T00:00:00.000000000',
#        '2017-01-05T00:00:00.000000000', '2017-01-06T00:00:00.000000000',
#        '2017-01-07T00:00:00.000000000', '2017-01-08T00:00:00.000000000',
#        '2017-01-09T00:00:00.000000000', '2017-01-10T00:00:00.000000000',
#        '2017-01-11T00:00:00.000000000', '2017-01-12T00:00:00.000000000',
#        '2017-01-13T00:00:00.000000000', '2017-01-14T00:00:00.000000000',
#        '2017-01-15T00:00:00.000000000', '2017-01-16T00:00:00.000000000',
#        '2017-01-17T00:00:00.000000000', '2017-01-18T00:00:00.000000000',
# ...

# %%
# drop la date pour chaque dataframe

# %%
data.dtypes
# Out:
# Unnamed: 0                           int64
# customer_unique_id                  object
# freight_value                      float64
# review_score                       float64
# score_freq                         float64
# price_y                            float64
# score_rec                          float64
# score_montant                      float64
# score_rfm                          float64
# order_purchase_timestamp    datetime64[ns]
# customer_city                       object
# order_id                            object
# product_id                          object
# seller_id                           object
# categorie_regroupee                 object
# dtype: object

# %%
data = data.dropna()

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0                  0
# customer_unique_id          0
# freight_value               0
# review_score                0
# score_freq                  0
# price_y                     0
# score_rec                   0
# score_montant               0
# score_rfm                   0
# order_purchase_timestamp    0
# customer_city               0
# order_id                    0
# product_id                  0
# seller_id                   0
# categorie_regroupee         0
# dtype: int64

# %% [markdown]
# ### K prototypes

# %%
import numpy as np
import pandas as pd
from kmodes.kprototypes import KPrototypes

# sélectionner les colonnes numériques et catégorielles
numeric_cols = [col for col in data.columns if data[col].dtype in [np.float64, np.int64]]
categorical_cols = [col for col in data.columns if data[col].dtype == 'object']

# séparer les colonnes numériques et catégorielles dans deux dataframes distincts
numeric_data = data[numeric_cols]
categorical_data = data[categorical_cols]




# standardiser les colonnes numériques


# combiner les deux dataframes (numériques et catégorielles)
data_combined = pd.concat([numeric_data, categorical_data], axis=1)

# initialiser l'algorithme K-Prototypes avec les paramètres nécessaires

# %%
kproto = KPrototypes(n_clusters=5, init='Huang',n_jobs = -1 , max_iter = 20, n_init=2, verbose=2,random_state=42)

 # entraîner le modèle sur les données combinées
clusters = kproto.fit_predict(data_combined, categorical=list(range(len(numeric_cols), data_combined.shape[1])))

# afficher les résultats
print("Cluster labels:", clusters)
# Out:
# Init: initializing centroids
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing clusters
# Starting iterations...
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 12381, ncost: 3092010618189.1587
# Run: 1, iteration: 1/20, moves: 20893, ncost: 3292343596310.8667
# Run: 2, iteration: 2/20, moves: 5520, ncost: 2943897898196.6914
# Run: 1, iteration: 2/20, moves: 11140, ncost: 2887981675515.707
# Run: 2, iteration: 3/20, moves: 3444, ncost: 2881575070616.153
# Run: 1, iteration: 3/20, moves: 5214, ncost: 2802987866624.296
# Run: 2, iteration: 4/20, moves: 2677, ncost: 2846745946355.138
# Run: 1, iteration: 4/20, moves: 2404, ncost: 2785237354922.042
# Run: 2, iteration: 5/20, moves: 2192, ncost: 2824709192145.331
# Run: 1, iteration: 5/20, moves: 1035, ncost: 2781710143834.667
# Run: 1, iteration: 6/20, moves: 495, ncost: 2780864809536.998
# Run: 2, iteration: 6/20, moves: 1808, ncost: 2810137551753.925
# ...

# %%
data_combined
# Out:
#        Unnamed: 0  freight_value  review_score  score_freq  price_y  \
# 68118       68118          31.67           1.0         1.0    72.89
# 26850       26850          15.56           1.0         1.0    59.50
# 48626       48626           2.83           1.0         1.0   134.97
# 5443         5443           9.34           1.0         1.0   100.00
# 50182       50182          10.96           5.0         1.0    29.99
# ...           ...            ...           ...         ...      ...
# 12618       12618           7.39           5.0         1.0     6.90
# 65178       65178           7.90           5.0         1.0   457.75
# 67822       67822           8.33           3.0         1.0    24.90
# 4647         4647           8.45           5.0         1.0   169.80
# 67034       67034           7.95           1.0         1.0    99.00
#
#        score_rec  score_montant  score_rfm                customer_unique_id  \
# ...

# %%
clusters
# Out:
# array([0, 3, 4, ..., 0, 1, 0], dtype=uint16)

# %%
data_combined["cluster"] = clusters

# %%
data_combined
# Out:
#        Unnamed: 0  freight_value  review_score  score_freq  price_y  \
# 68118       68118          31.67           1.0         1.0    72.89
# 26850       26850          15.56           1.0         1.0    59.50
# 48626       48626           2.83           1.0         1.0   134.97
# 5443         5443           9.34           1.0         1.0   100.00
# 50182       50182          10.96           5.0         1.0    29.99
# ...           ...            ...           ...         ...      ...
# 12618       12618           7.39           5.0         1.0     6.90
# 65178       65178           7.90           5.0         1.0   457.75
# 67822       67822           8.33           3.0         1.0    24.90
# 4647         4647           8.45           5.0         1.0   169.80
# 67034       67034           7.95           1.0         1.0    99.00
#
#        score_rec  score_montant  score_rfm                customer_unique_id  \
# ...

# %%
#numeric_data["cluster"] = clusters

# %%
#data["cluster"] = clusters

# %%
data
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 12618       12618  21dbe8eabd00b34492a939c540e2b1a7           7.39
# 65178       65178  afbcfd0b9c5233e7ccc73428526fbb52           7.90
# 67822       67822  b701bebbdf478f5500348f03aff62121           8.33
# 4647         4647  0c6d7218d5f3fa14514fd29865269993           8.45
# 67034       67034  b4dcade04bc548b7e3b0243c801f8c26           7.95
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
""" from sklearn.manifold import TSNE

# create the t-SNE object with the desired parameters
tsne = TSNE()

# fit and transform the data
reduced_data = tsne.fit_transform(numeric_data)
 """
# Out:
# ' from sklearn.manifold import TSNE\n\n# create the t-SNE object with the desired parameters\ntsne = TSNE()\n\n# fit and transform the data\nreduced_data = tsne.fit_transform(numeric_data)\n '

# %%
numeric_data
# Out:
#        Unnamed: 0  freight_value  review_score  score_freq  price_y  \
# 68118       68118          31.67           1.0         1.0    72.89
# 26850       26850          15.56           1.0         1.0    59.50
# 48626       48626           2.83           1.0         1.0   134.97
# 5443         5443           9.34           1.0         1.0   100.00
# 50182       50182          10.96           5.0         1.0    29.99
# ...           ...            ...           ...         ...      ...
# 12618       12618           7.39           5.0         1.0     6.90
# 65178       65178           7.90           5.0         1.0   457.75
# 67822       67822           8.33           3.0         1.0    24.90
# 4647         4647           8.45           5.0         1.0   169.80
# 67034       67034           7.95           1.0         1.0    99.00
#
#        score_rec  score_montant  score_rfm
# 68118        1.0            3.0        5.0
# 26850        1.0            2.0        4.0
# ...

# %%
""" # plot the transformed data
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=numeric_data["score_montant"])
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2") """
# Out:
# ' # plot the transformed data\nplt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=numeric_data["score_montant"])\nplt.xlabel("t-SNE Dimension 1")\nplt.ylabel("t-SNE Dimension 2") '

# %%
""" plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=numeric_data["cluster"])
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2") """
# Out:
# ' plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=numeric_data["cluster"])\nplt.xlabel("t-SNE Dimension 1")\nplt.ylabel("t-SNE Dimension 2") '

# %%
data.to_csv("df_cluster_test.csv")

# %%
data
# Out:
#        Unnamed: 0                customer_unique_id  freight_value  \
# 68118       68118  b7d76e111c89f7ebf14761390f0f7d17          31.67
# 26850       26850  4854e9b3feff728c13ee5fc7d1547e92          15.56
# 48626       48626  830d5b7aaa3b6f1e9ad63703bec97d23           2.83
# 5443         5443  0eb1ee9dba87f5b36b4613a65074337c           9.34
# 50182       50182  87776adb449c551e74c13fc34f036105          10.96
# ...           ...                               ...            ...
# 12618       12618  21dbe8eabd00b34492a939c540e2b1a7           7.39
# 65178       65178  afbcfd0b9c5233e7ccc73428526fbb52           7.90
# 67822       67822  b701bebbdf478f5500348f03aff62121           8.33
# 4647         4647  0c6d7218d5f3fa14514fd29865269993           8.45
# 67034       67034  b4dcade04bc548b7e3b0243c801f8c26           7.95
#
#        review_score  score_freq  price_y  score_rec  score_montant  score_rfm  \
# 68118           1.0         1.0    72.89        1.0            3.0        5.0
# ...

# %%
# mise a jour , ARI

# %%
from sklearn.metrics.cluster import adjusted_rand_score

# %%
data_2016 = data_2016.dropna()

# %%
data_2016.columns
# Out:
# Index(['Unnamed: 0', 'customer_unique_id', 'freight_value', 'review_score',
#        'score_freq', 'price_y', 'score_rec', 'score_montant', 'score_rfm',
#        'order_purchase_timestamp', 'customer_city', 'order_id', 'product_id',
#        'seller_id', 'categorie_regroupee'],
#       dtype='object')

# %%
data_2016 = data_2016[[ 'freight_value', 'review_score', 'score_freq', 'score_rec',
        'score_montant', 
       'customer_city', 'categorie_regroupee']]

# %%
import numpy as np
import pandas as pd
from kmodes.kprototypes import KPrototypes

# sélectionner les colonnes numériques et catégorielles
numeric_cols = [col for col in data_2016.columns if data_2016[col].dtype in [np.float64, np.int64]]
categorical_cols = [col for col in data_2016.columns if data_2016[col].dtype == 'object']

# séparer les colonnes numériques et catégorielles dans deux dataframes distincts
numeric_data = data_2016[numeric_cols]
categorical_data = data_2016[categorical_cols]




# standardiser les colonnes numériques

# %%
# combiner les deux dataframes (numériques et catégorielles)
data_combined = pd.concat([numeric_data, categorical_data], axis=1)

# %%
data_combined.dtypes
# Out:
# freight_value          float64
# review_score           float64
# score_freq             float64
# score_rec              float64
# score_montant          float64
# customer_city           object
# categorie_regroupee     object
# dtype: object

# %%
# initialiser l'algorithme K-Prototypes avec les paramètres nécessaires
kproto = KPrototypes(n_clusters=5, init='Huang',n_jobs = -1 , max_iter = 20, n_init=2, verbose=2,random_state=42)

 # entraîner le modèle sur les données combinées
clusters_2016 = kproto.fit_predict(data_combined, categorical=list(range(len(numeric_cols), data_combined.shape[1])))

# afficher les résultats
print("Cluster labels:", clusters)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 36, ncost: 10260.269384807898
# Init: initializing centroids
# Init: initializing clusters
# Run: 1, iteration: 2/20, moves: 50, ncost: 8862.381019360753
# Starting iterations...
# Run: 1, iteration: 3/20, moves: 22, ncost: 8477.062220020865
# Run: 1, iteration: 4/20, moves: 10, ncost: 8455.220418207873
# Run: 2, iteration: 1/20, moves: 107, ncost: 19093.640478491594
# Run: 1, iteration: 5/20, moves: 7, ncost: 8439.527891965177
# Run: 2, iteration: 2/20, moves: 93, ncost: 15744.548758822591
# Run: 1, iteration: 6/20, moves: 11, ncost: 8403.74446239763
# Run: 1, iteration: 7/20, moves: 16, ncost: 8373.498140968637
# Run: 2, iteration: 3/20, moves: 47, ncost: 12659.464096647895
# Run: 1, iteration: 8/20, moves: 5, ncost: 8368.488823318325
# ...

# %%
data_2016_2017 = data_2016_2017[[ 'freight_value', 'review_score', 'score_freq',
        'score_montant', 
       'customer_city', 'categorie_regroupee']]

# %%
import numpy as np
import pandas as pd
from kmodes.kprototypes import KPrototypes

# sélectionner les colonnes numériques et catégorielles
numeric_cols = [col for col in data_2016_2017.columns if data_2016_2017[col].dtype in [np.float64, np.int64]]
categorical_cols = [col for col in data_2016_2017.columns if data_2016_2017[col].dtype == 'object']

# séparer les colonnes numériques et catégorielles dans deux dataframes distincts
numeric_data = data_2016_2017[numeric_cols]
categorical_data = data_2016_2017[categorical_cols]






# combiner les deux dataframes (numériques et catégorielles)
data_combined = pd.concat([numeric_data, categorical_data], axis=1)

# initialiser l'algorithme K-Prototypes avec les paramètres nécessaires
kproto = KPrototypes(n_clusters=5, init='Huang',n_jobs = -1 , max_iter = 20, n_init=2, verbose=2,random_state=42)

 # entraîner le modèle sur les données combinées
clusters_2016_2017 = kproto.fit_predict(data_combined, categorical=list(range(len(numeric_cols), data_combined.shape[1])))

# afficher les résultats
print("Cluster labels:", clusters)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 17300, ncost: 8886327.775769616
# Run: 1, iteration: 1/20, moves: 28017, ncost: 10460171.921253279
# Run: 1, iteration: 2/20, moves: 22771, ncost: 8623454.006277036
# Run: 2, iteration: 2/20, moves: 27752, ncost: 7797220.976351667
# Run: 1, iteration: 3/20, moves: 22142, ncost: 7264095.903109976
# Run: 2, iteration: 3/20, moves: 23887, ncost: 6842629.666135688
# Run: 1, iteration: 4/20, moves: 15674, ncost: 6396221.160898129
# Run: 2, iteration: 4/20, moves: 15094, ncost: 6183960.996227921
# Run: 1, iteration: 5/20, moves: 9315, ncost: 5896814.029015291
# Run: 2, iteration: 5/20, moves: 10593, ncost: 5586429.356904731
# Run: 1, iteration: 6/20, moves: 8937, ncost: 5346469.188289362
# Run: 2, iteration: 6/20, moves: 10216, ncost: 5093506.877785135
# ...

# %%
import numpy as np
import pandas as pd
from kmodes.kprototypes import KPrototypes

# sélectionner les colonnes numériques et catégorielles
numeric_cols = [col for col in data_pourcent.columns if data_pourcent[col].dtype in [np.float64, np.int64]]
categorical_cols = [col for col in data_pourcent.columns if data_pourcent[col].dtype == 'object']

# séparer les colonnes numériques et catégorielles dans deux dataframes distincts
numeric_data = data_pourcent[numeric_cols]
categorical_data = data_pourcent[categorical_cols]




# standardiser les colonnes numériques
numeric_data = (numeric_data - numeric_data.mean()) / numeric_data.std()

# combiner les deux dataframes (numériques et catégorielles)
data_combined = pd.concat([numeric_data, categorical_data], axis=1)

# initialiser l'algorithme K-Prototypes avec les paramètres nécessaires
kproto = KPrototypes(n_clusters=5, init='Huang',n_jobs = -1 , max_iter = 20, n_init=2, verbose=2,random_state=42)

 # entraîner le modèle sur les données combinées
clusters_pourcent = kproto.fit_predict(data_combined, categorical=list(range(len(numeric_cols), data_combined.shape[1])))

# afficher les résultats
print("Cluster labels:", clusters)
# Out:
# Init: initializing centroids
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing clusters
# Starting iterations...
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 22459, ncost: 634498.6171935512
# Run: 2, iteration: 1/20, moves: 23601, ncost: 604396.4655552033
# Run: 1, iteration: 2/20, moves: 8326, ncost: 624837.3868128904
# Run: 2, iteration: 2/20, moves: 9581, ncost: 594568.6178363217
# Run: 1, iteration: 3/20, moves: 2814, ncost: 623023.588946396
# Run: 2, iteration: 3/20, moves: 5980, ncost: 592609.968556724
# Run: 1, iteration: 4/20, moves: 723, ncost: 621624.6181089343
# Run: 2, iteration: 4/20, moves: 1200, ncost: 592420.9885278028
# Run: 1, iteration: 5/20, moves: 595, ncost: 620760.0777364795
# Run: 2, iteration: 5/20, moves: 188, ncost: 592388.2686644549
# Run: 1, iteration: 6/20, moves: 461, ncost: 620567.8148754599
# Run: 2, iteration: 6/20, moves: 123, ncost: 592372.3867264929
# ...

# %%
adjusted_rand_score(clusters[:294], clusters_2016)
# Out:
# -0.0028070717074960443

# %%
print(clusters)
# Out:
# [0 3 4 ... 0 1 0]

# %%
print(clusters[:294])
# Out:
# [0 3 4 1 4 0 3 1 4 1 4 0 1 4 3 2 2 0 3 4 2 0 3 2 0 2 4 4 0 1 2 4 0 4 1 1 2
#  1 0 0 2 1 1 1 2 1 2 1 1 2 2 1 3 3 3 3 2 3 1 1 1 2 1 3 3 4 0 2 3 4 2 0 0 3
#  4 2 1 2 0 2 0 3 0 1 2 1 3 3 3 1 3 1 0 1 1 3 4 2 4 1 4 1 0 0 4 0 4 4 2 1 1
#  4 1 2 0 4 3 4 3 4 3 4 1 1 0 4 0 0 3 4 2 1 2 1 2 0 2 1 4 0 2 0 3 4 0 3 3 2
#  1 0 2 4 4 2 3 2 0 3 1 2 3 3 3 3 3 1 2 0 3 3 0 2 0 0 3 1 4 0 1 1 3 1 2 1 4
#  0 1 2 4 1 4 4 3 0 4 2 0 2 3 3 4 2 3 4 0 1 2 1 4 0 4 3 1 0 2 0 2 2 0 2 4 3
#  0 2 4 1 2 3 1 2 1 4 3 2 2 1 3 2 0 0 1 2 3 2 2 4 1 4 4 2 1 2 3 4 3 2 1 2 1
#  3 4 0 1 3 0 0 3 4 3 0 0 2 0 3 2 2 3 4 2 4 1 1 2 4 0 0 4 4 4 2 2 1 1 2]

# %%
print(clusters_2016_2017[:294])
# Out:
# [3 0 4 4 4 4 0 0 0 0 4 4 0 4 3 0 4 0 0 3 0 4 4 3 0 4 0 4 0 0 0 1 0 0 3 4 0
#  0 0 0 0 0 3 3 0 0 0 4 0 0 4 4 0 4 0 3 3 4 3 0 0 0 0 0 3 0 0 0 4 4 0 3 4 0
#  3 0 4 0 3 0 3 4 0 0 2 0 4 0 0 0 4 0 0 4 0 4 0 4 4 3 4 0 4 4 0 2 0 4 0 0 4
#  0 0 0 0 4 4 0 4 0 4 0 4 0 4 0 4 4 4 0 0 0 0 0 0 1 4 1 0 0 4 4 0 0 0 4 0 4
#  4 0 4 0 0 4 3 0 0 4 4 0 0 0 4 4 0 4 4 0 4 0 0 0 4 4 0 0 0 4 0 0 3 0 4 0 4
#  4 4 0 0 0 0 0 0 1 0 4 4 0 0 4 0 4 3 4 0 0 4 4 4 0 4 0 4 4 3 4 3 4 1 4 0 0
#  4 0 0 0 0 1 0 0 0 4 4 0 0 0 0 0 4 0 0 3 0 4 0 0 0 3 4 4 0 0 0 0 3 0 1 0 4
#  0 0 0 4 4 0 0 3 0 4 4 0 3 4 0 4 0 4 4 0 4 4 0 4 0 0 0 3 0 4 3 0 0 3 0]

# %%
adjusted_rand_score(clusters[:92791], clusters_2016_2017)
# Out:
# 3.7691967673693646e-05

# %%
len(clusters_2016_2017)
# Out:
# 92791

# %%
adjusted_rand_score(clusters[:83511], clusters_pourcent)
# Out:
# -1.049703990599178e-05

# %%
adjusted_rand_score(clusters_pourcent[:92791], clusters_2016_2017[:83511])
# Out:
# 0.024269931811150662

# %%
adjusted_rand_score(clusters_2016, clusters_2016_2017[:294])
# Out:
# 0.0195165845203688
