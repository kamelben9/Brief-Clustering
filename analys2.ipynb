# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
import numpy as np

# %%
data = pd.read_csv("data_analys.csv")

# %%
data
# Out:
#         Unnamed: 0                       customer_id  \
# 0                0  08c5351a6aca1c1589a38f244edeee9d
# 1                1  08c5351a6aca1c1589a38f244edeee9d
# 2                2  683c54fc24d40ee9f8a6fc179fd9856c
# 3                3  86dc2ffce2dfff336de2f386a786e574
# 4                4  86dc2ffce2dfff336de2f386a786e574
# ...            ...                               ...
# 112367      112367  448945bc713d98b6726e82eda6249b9e
# 112368      112368  e60df9449653a95af4549bbfcb18a6eb
# 112369      112369  448945bc713d98b6726e82eda6249b9e
# 112370      112370  448945bc713d98b6726e82eda6249b9e
# 112371      112371  4b7decb9b58e2569548b8b4c8e20e8d7
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 0       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 1       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 2       4854e9b3feff728c13ee5fc7d1547e92                     99025
# ...

# %%
part_marche = data.groupby(data.customer_state).sum()
# Out:
# /tmp/ipykernel_9936/3782959267.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   part_marche = data.groupby(data.customer_state).sum()

# %%
part_marche = part_marche.reset_index()

# %%
part_marche
# Out:
#    customer_state  Unnamed: 0  customer_zip_code_prefix  order_item_id  \
# 0              AC     3924514                   6432120            115
# 1              AL    22329167                  25462678            493
# 2              AM     8561164                  11328553            194
# 3              AP     4033488                   5581768            102
# 4              BA   205329066                 166077334           4418
# 5              CE    78455786                  90688724           1703
# 6              DF   139658561                 173088010           2826
# 7              ES   121746078                  65546509           2555
# 8              GO   126213901                 173684518           2921
# 9              MA    41658525                  53774950            952
# 10             MG   719253606                 461556708          15491
# 11             MS    47015836                  65783862            990
# ...

# %%
# %matplotlib inline

# %%
sns.barplot(x = part_marche.customer_state , y = part_marche.review_score)
# Out:
# <AxesSubplot: xlabel='customer_state', ylabel='review_score'>

# %%
data.product_category_name.unique()
# Out:
# array(['moveis_decoracao', 'telefonia', 'beleza_saude', 'bebes',
#        'relogios_presentes', 'brinquedos', 'fashion_calcados',
#        'esporte_lazer', 'automotivo', 'cama_mesa_banho',
#        'informatica_acessorios', 'consoles_games',
#        'utilidades_domesticas', 'perfumaria', 'climatizacao',
#        'ferramentas_jardim', nan, 'moveis_escritorio', 'cool_stuff',
#        'telefonia_fixa', 'eletronicos', 'market_place',
#        'industria_comercio_e_negocios', 'livros_tecnicos',
#        'fashion_roupa_feminina', 'fashion_roupa_masculina', 'pet_shop',
#        'fashion_bolsas_e_acessorios', 'audio', 'fraldas_higiene',
#        'livros_interesse_geral', 'alimentos', 'papelaria',
#        'moveis_quarto', 'musica', 'eletroportateis', 'eletrodomesticos_2',
#        'fashion_underwear_e_moda_praia', 'agro_industria_e_comercio',
#        'casa_conforto_2', 'malas_acessorios',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
# ...

# %%
data_segment = data.groupby(data.product_category_name).sum()
# Out:
# /tmp/ipykernel_9936/833033322.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_segment = data.groupby(data.product_category_name).sum()

# %%
data_segment = data_segment.reset_index()

# %%
data_segment.columns
# Out:
# Index(['product_category_name', 'Unnamed: 0', 'customer_zip_code_prefix',
#        'order_item_id', 'price_x', 'freight_value', 'review_score',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'diff_days', 'dummy',
#        'score_freq', 'price_y', 'score_rec', 'score_montant', 'score_rfm'],
#       dtype='object')

# %%
data_segment.sort_values(by = ["price_x"],inplace = True,ascending=False)

# %%
data_segment
# Out:
#             product_category_name  Unnamed: 0  customer_zip_code_prefix  \
# 11                   beleza_saude   592962717                 333311583
# 66             relogios_presentes   376824092                 213341650
# 13                cama_mesa_banho   614244188                 350251436
# 32                  esporte_lazer   465662831                 308304453
# 44         informatica_acessorios   445080373                 282270165
# ..                            ...         ...                       ...
# 41                         flores     1931191                    959088
# 17              cds_dvds_musicais      437142                    628547
# 15                casa_conforto_2     1181996                    872061
# 37  fashion_roupa_infanto_juvenil      343384                    267614
# 67             seguros_e_servicos       29774                    148880
#
#     order_item_id     price_x  freight_value  review_score  \
# ...

# %%
data_segment.dropna()
# Out:
#             product_category_name  Unnamed: 0  customer_zip_code_prefix  \
# 11                   beleza_saude   592962717                 333311583
# 66             relogios_presentes   376824092                 213341650
# 13                cama_mesa_banho   614244188                 350251436
# 32                  esporte_lazer   465662831                 308304453
# 44         informatica_acessorios   445080373                 282270165
# ..                            ...         ...                       ...
# 41                         flores     1931191                    959088
# 17              cds_dvds_musicais      437142                    628547
# 15                casa_conforto_2     1181996                    872061
# 37  fashion_roupa_infanto_juvenil      343384                    267614
# 67             seguros_e_servicos       29774                    148880
#
#     order_item_id     price_x  freight_value  review_score  \
# ...

# %%
sns.barplot(x = data_segment.product_category_name,y = data_segment.price_x)
# Out:
# <AxesSubplot: xlabel='product_category_name', ylabel='price_x'>

# %%
data.product_category_name.unique()
# Out:
# array(['moveis_decoracao', 'telefonia', 'beleza_saude', 'bebes',
#        'relogios_presentes', 'brinquedos', 'fashion_calcados',
#        'esporte_lazer', 'automotivo', 'cama_mesa_banho',
#        'informatica_acessorios', 'consoles_games',
#        'utilidades_domesticas', 'perfumaria', 'climatizacao',
#        'ferramentas_jardim', nan, 'moveis_escritorio', 'cool_stuff',
#        'telefonia_fixa', 'eletronicos', 'market_place',
#        'industria_comercio_e_negocios', 'livros_tecnicos',
#        'fashion_roupa_feminina', 'fashion_roupa_masculina', 'pet_shop',
#        'fashion_bolsas_e_acessorios', 'audio', 'fraldas_higiene',
#        'livros_interesse_geral', 'alimentos', 'papelaria',
#        'moveis_quarto', 'musica', 'eletroportateis', 'eletrodomesticos_2',
#        'fashion_underwear_e_moda_praia', 'agro_industria_e_comercio',
#        'casa_conforto_2', 'malas_acessorios',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
# ...

# %%
categories_pt = ['moveis_decoracao', 'telefonia', 'beleza_saude', 'bebes',
       'relogios_presentes', 'brinquedos', 'fashion_calcados',
       'esporte_lazer', 'automotivo', 'cama_mesa_banho',
       'informatica_acessorios', 'consoles_games',
       'utilidades_domesticas', 'perfumaria', 'climatizacao',
       'ferramentas_jardim', 'moveis_escritorio', 'cool_stuff',
       'telefonia_fixa', 'eletronicos', 'market_place',
       'industria_comercio_e_negocios', 'livros_tecnicos',
       'fashion_roupa_feminina', 'fashion_roupa_masculina', 'pet_shop',
       'fashion_bolsas_e_acessorios', 'audio', 'fraldas_higiene',
       'livros_interesse_geral', 'alimentos', 'papelaria',
       'moveis_quarto', 'musica', 'eletroportateis', 'eletrodomesticos_2',
       'fashion_underwear_e_moda_praia', 'agro_industria_e_comercio',
       'casa_conforto_2', 'malas_acessorios',
       'moveis_cozinha_area_de_servico_jantar_e_jardim',
       'seguros_e_servicos', 'moveis_sala', 'instrumentos_musicais',
       'pcs', 'construcao_ferramentas_construcao', 'dvds_blu_ray',
       'tablets_impressao_imagem', 'casa_conforto',
       'construcao_ferramentas_jardim', 'casa_construcao',
       'eletrodomesticos', 'cine_foto',
       'construcao_ferramentas_seguranca', 'livros_importados', 'artes',
       'bebidas', 'fashion_esporte', 'alimentos_bebidas',
       'sinalizacao_e_seguranca', 'la_cuisine',
       'construcao_ferramentas_ferramentas', 'pc_gamer',
       'artigos_de_natal', 'moveis_colchao_e_estofado',
       'artes_e_artesanato', 'fashion_roupa_infanto_juvenil',
       'portateis_casa_forno_e_cafe', 'cds_dvds_musicais',
       'construcao_ferramentas_iluminacao', 'artigos_de_festas', 'flores',
       'portateis_cozinha_e_preparadores_de_alimentos']

# %%
liste = ['Meubles et décoration', 'Téléphonie', 'Beauté et santé', 'Bébés',
'Montres et cadeaux', 'Jouets', 'Mode et chaussures',
'Sport et loisirs', 'Automobile', 'Lit, table et salle de bain',
'Informatique et accessoires', 'Consoles et jeux',
'Articles ménagers', 'Parfumerie', 'Climatisation',
'Outils de jardin', 'Meubles de bureau', 'Cool Stuff',
'Téléphonie fixe', 'Electroniques', 'Market Place',
'Industrie, commerce et affaires', 'Livres techniques','Mode vêtements féminins', 'Mode vêtements masculins', 'Animalerie',
'Mode sacs et accessoires', 'Audio', 'Couches et hygiène',
'Livres dintérêt général', 'Aliments', 'Papeterie',
'Meubles de chambre', 'Musique', 'Petits électroménagers', 'Électroménagers',
'Mode sous-vêtements et mode plage', 'Agro-industrie et commerce',
'Maison confort', 'Valises et accessoires',
'Meubles de cuisine, de service, de salle à manger et de jardin',
'Assurances et services', 'Meubles de salon', 'Instruments de musique',
'PC', 'Construction outils de construction', 'DVDs Blu-Ray',
'Tablettes impression image', 'Maison confort',
'Construction outils de jardin', 'Construction de maisons',
'Électroménagers', 'Cinéma et photo','Construction outils de sécurité', 'Livres importés', 'Arts',
'Boissons', 'Mode sport', 'Aliments et boissons',
'Signalisation et sécurité', 'La cuisine',
'Construction outils doutils', 'PC gamer',
'Articles de Noël', 'Meubles matelas et canapés',
'Arts et artisanat', 'Mode vêtements enfants et jeunes',
'Petits appareils pour la maison, fours et café',
'CDs, DVDs musicaux', 'Construction outils déclairage', 'Articles de fête', 'Fleurs',
'Petits appareils pour la cuisine et préparateurs daliments']

liste_tech =     ["Téléphonie","Informatique et accessoires","Consoles et jeux","Téléphonie fixe","Electroniques","PC,Tablettes", "impression image","CDs", "DVDs musicaux","PC gamer","Cinéma et photo","PC","Audio"]
list = set(liste)
list_tech = set(liste_tech)
b =  list.difference(list_tech)

len(b)
# Out:
# 62

# %%
data
# Out:
#         Unnamed: 0                       customer_id  \
# 0                0  08c5351a6aca1c1589a38f244edeee9d
# 1                1  08c5351a6aca1c1589a38f244edeee9d
# 2                2  683c54fc24d40ee9f8a6fc179fd9856c
# 3                3  86dc2ffce2dfff336de2f386a786e574
# 4                4  86dc2ffce2dfff336de2f386a786e574
# ...            ...                               ...
# 112367      112367  448945bc713d98b6726e82eda6249b9e
# 112368      112368  e60df9449653a95af4549bbfcb18a6eb
# 112369      112369  448945bc713d98b6726e82eda6249b9e
# 112370      112370  448945bc713d98b6726e82eda6249b9e
# 112371      112371  4b7decb9b58e2569548b8b4c8e20e8d7
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 0       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 1       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 2       4854e9b3feff728c13ee5fc7d1547e92                     99025
# ...

# %%
dictionnaire = dict(zip(categories_pt, liste))

# %%
dictionnaire
# Out:
# {'moveis_decoracao': 'Meubles et décoration',
#  'telefonia': 'Téléphonie',
#  'beleza_saude': 'Beauté et santé',
#  'bebes': 'Bébés',
#  'relogios_presentes': 'Montres et cadeaux',
#  'brinquedos': 'Jouets',
#  'fashion_calcados': 'Mode et chaussures',
#  'esporte_lazer': 'Sport et loisirs',
#  'automotivo': 'Automobile',
#  'cama_mesa_banho': 'Lit, table et salle de bain',
#  'informatica_acessorios': 'Informatique et accessoires',
#  'consoles_games': 'Consoles et jeux',
#  'utilidades_domesticas': 'Articles ménagers',
#  'perfumaria': 'Parfumerie',
#  'climatizacao': 'Climatisation',
#  'ferramentas_jardim': 'Outils de jardin',
#  'moveis_escritorio': 'Meubles de bureau',
#  'cool_stuff': 'Cool Stuff',
#  'telefonia_fixa': 'Téléphonie fixe',
#  'eletronicos': 'Electroniques',
#  'market_place': 'Market Place',
#  'industria_comercio_e_negocios': 'Industrie, commerce et affaires',
#  'livros_tecnicos': 'Livres techniques',
#  'fashion_roupa_feminina': 'Mode vêtements féminins',
# ...

# %%
liste_mobilier = ['Meubles et décoration','Lit, table et salle de bain',"articles ménagers","climatisation","Meubles de bureau",
"Meubles de chambre",'Petits électroménagers', 'Électroménagers',
'Maison confort','Meubles de cuisine, de service, de salle à manger et de jardin','Meubles de salon','Maison confort','Articles de Noël',
 'Meubles matelas et canapés','Petits appareils pour la maison, fours et café','Petits appareils pour la cuisine et préparateurs daliments','Articles ménagers','La cuisine',
 'Climatisation',]

# %%
list_mobilier = set(liste_mobilier)

# %%
c = b.difference(list_mobilier)
len(c)
# Out:
# 46

# %%
c
# Out:
# {'Agro-industrie et commerce',
#  'Aliments',
#  'Aliments et boissons',
#  'Animalerie',
#  'Articles de fête',
#  'Arts',
#  'Arts et artisanat',
#  'Assurances et services',
#  'Automobile',
#  'Beauté et santé',
#  'Boissons',
#  'Bébés',
#  'CDs, DVDs musicaux',
#  'Construction de maisons',
#  'Construction outils de construction',
#  'Construction outils de jardin',
#  'Construction outils de sécurité',
#  'Construction outils doutils',
#  'Construction outils déclairage',
#  'Cool Stuff',
#  'Couches et hygiène',
#  'DVDs Blu-Ray',
#  'Fleurs',
#  'Industrie, commerce et affaires',
#  'Instruments de musique',
#  'Jouets',
#  'Livres dintérêt général',
#  'Livres importés',
#  'Livres techniques',
#  'Market Place',
#  'Mode et chaussures',
#  'Mode sacs et accessoires',
#  'Mode sous-vêtements et mode plage',
#  'Mode sport',
#  'Mode vêtements enfants et jeunes',
#  'Mode vêtements féminins',
#  'Mode vêtements masculins',
#  'Montres et cadeaux',
#  'Musique',
# ...

# %%
liste_bricolage_jardin = ['Agro-industrie et commerce',
 'Construction de maisons',
 'Construction outils de construction',
 'Construction outils de jardin',
 'Construction outils de sécurité',
 'Construction outils doutils',
 'Construction outils déclairage',
 'Cool Stuff',
 'Outils de jardin',
 'Signalisation et sécurité', 'Automobile',
]

# %%
list_bricolage_jardin = set(liste_bricolage_jardin)

# %%
d = c.difference(list_bricolage_jardin)

# %%
len(d)
# Out:
# 35

# %%
d
# Out:
# {'Aliments',
#  'Aliments et boissons',
#  'Animalerie',
#  'Articles de fête',
#  'Arts',
#  'Arts et artisanat',
#  'Assurances et services',
#  'Beauté et santé',
#  'Boissons',
#  'Bébés',
#  'CDs, DVDs musicaux',
#  'Couches et hygiène',
#  'DVDs Blu-Ray',
#  'Fleurs',
#  'Industrie, commerce et affaires',
#  'Instruments de musique',
#  'Jouets',
#  'Livres dintérêt général',
#  'Livres importés',
#  'Livres techniques',
#  'Market Place',
#  'Mode et chaussures',
#  'Mode sacs et accessoires',
#  'Mode sous-vêtements et mode plage',
#  'Mode sport',
#  'Mode vêtements enfants et jeunes',
#  'Mode vêtements féminins',
#  'Mode vêtements masculins',
#  'Montres et cadeaux',
#  'Musique',
#  'Papeterie',
#  'Parfumerie',
#  'Sport et loisirs',
#  'Tablettes impression image',
#  'Valises et accessoires'}

# %%
liste_mode = ['Mode et chaussures',
 'Mode sacs et accessoires',
 'Mode sous-vêtements et mode plage',
 'Mode sport',
 'Mode vêtements enfants et jeunes',
 'Mode vêtements féminins',
 'Mode vêtements masculins',
 'Montres et cadeaux']

# %%
list_mode = set(liste_mode)

# %%
e = d.difference(list_mode)

# %%
e
# Out:
# {'Aliments',
#  'Aliments et boissons',
#  'Animalerie',
#  'Articles de fête',
#  'Arts',
#  'Arts et artisanat',
#  'Assurances et services',
#  'Beauté et santé',
#  'Boissons',
#  'Bébés',
#  'CDs, DVDs musicaux',
#  'Couches et hygiène',
#  'DVDs Blu-Ray',
#  'Fleurs',
#  'Industrie, commerce et affaires',
#  'Instruments de musique',
#  'Jouets',
#  'Livres dintérêt général',
#  'Livres importés',
#  'Livres techniques',
#  'Market Place',
#  'Musique',
#  'Papeterie',
#  'Parfumerie',
#  'Sport et loisirs',
#  'Tablettes impression image',
#  'Valises et accessoires'}

# %%
liste_livre_papeterie = [
 'Livres dintérêt général',
 'Livres importés',
 'Livres techniques',
 'Papeterie',
 'Tablettes impression image',
]

# %%
list_livre_papeterie = set(liste_livre_papeterie)

# %%
f= e.difference(liste_livre_papeterie)

# %%
len(f)
# Out:
# 22

# %%
f
# Out:
# {'Aliments',
#  'Aliments et boissons',
#  'Animalerie',
#  'Articles de fête',
#  'Arts',
#  'Arts et artisanat',
#  'Assurances et services',
#  'Beauté et santé',
#  'Boissons',
#  'Bébés',
#  'CDs, DVDs musicaux',
#  'Couches et hygiène',
#  'DVDs Blu-Ray',
#  'Fleurs',
#  'Industrie, commerce et affaires',
#  'Instruments de musique',
#  'Jouets',
#  'Market Place',
#  'Musique',
#  'Parfumerie',
#  'Sport et loisirs',
#  'Valises et accessoires'}

# %%
liste_alimentation = ['Aliments',
 'Aliments et boissons',
 'Boissons',
 'Bébés',
 ]
list_alimentatation = set(liste_alimentation)
g = f.difference(list_alimentatation)

# %%
g
# Out:
# {'Animalerie',
#  'Articles de fête',
#  'Arts',
#  'Arts et artisanat',
#  'Assurances et services',
#  'Beauté et santé',
#  'CDs, DVDs musicaux',
#  'Couches et hygiène',
#  'DVDs Blu-Ray',
#  'Fleurs',
#  'Industrie, commerce et affaires',
#  'Instruments de musique',
#  'Jouets',
#  'Market Place',
#  'Musique',
#  'Parfumerie',
#  'Sport et loisirs',
#  'Valises et accessoires'}

# %%
liste_art = ['Arts',
 'Arts et artisanat',
 'CDs, DVDs musicaux',
 'DVDs Blu-Ray',
 'Musique',
 'Instruments de musique',
]

# %%
list_art = set(liste_art)

# %%
h = g.difference(liste_art)

# %%
h
# Out:
# {'Animalerie',
#  'Articles de fête',
#  'Assurances et services',
#  'Beauté et santé',
#  'Couches et hygiène',
#  'Fleurs',
#  'Industrie, commerce et affaires',
#  'Jouets',
#  'Market Place',
#  'Parfumerie',
#  'Sport et loisirs',
#  'Valises et accessoires'}

# %%
liste_parfumerie = ["Parfumerie", 'Fleurs']

# %%
list_parfumerie = set(liste_parfumerie)

# %%
i = h.difference(list_parfumerie)

# %%
i
# Out:
# {'Animalerie',
#  'Articles de fête',
#  'Assurances et services',
#  'Beauté et santé',
#  'Couches et hygiène',
#  'Industrie, commerce et affaires',
#  'Jouets',
#  'Market Place',
#  'Sport et loisirs',
#  'Valises et accessoires'}

# %%
liste_beaute_sante = [
 'Beauté et santé',
 'Couches et hygiène',
]

# %%
list_beaute_sante = set(liste_beaute_sante)

# %%
j = i.difference(list_beaute_sante)

# %%
j
# Out:
# {'Animalerie',
#  'Articles de fête',
#  'Assurances et services',
#  'Industrie, commerce et affaires',
#  'Jouets',
#  'Market Place',
#  'Sport et loisirs',
#  'Valises et accessoires'}

# %%
liste_mode_de_vie = ['Sport et loisirs',
 'Valises et accessoires']

# %%
list_mode_de_vie = set(liste_mode_de_vie)

# %%
k = j.difference(list_mode_de_vie)

# %%
k
# Out:
# {'Animalerie',
#  'Articles de fête',
#  'Assurances et services',
#  'Industrie, commerce et affaires',
#  'Jouets',
#  'Market Place'}

# %%
liste_autre = ['Animalerie',
 'Articles de fête',
 'Assurances et services',
 'Industrie, commerce et affaires',
 'Jouets',
 'Market Place',
 'N/A']

# %%
def categorie_regroupee(cat):
    if cat in liste_tech:
        return "Technologie"
    elif cat in liste_mobilier:
        return "Mobilier"
    elif cat in liste_bricolage_jardin:
        return "Bricolage et Jardin"
    elif cat in liste_mode:
        return "Mode"
    elif cat in liste_livre_papeterie:
        return "Livre et Papeterie"
    elif cat in liste_alimentation:
        return "Alimentation"
    elif cat in liste_art:
        return "Art"
    elif cat in liste_parfumerie:
        return "Parfumerie"
    elif cat in liste_beaute_sante:
        return "Beauté et Santé"
    elif cat in liste_mode_de_vie:
        return "Mode de Vie"
    else:
        return "Autre"

# %%
categories_dict = {
}

# %%
data["product_category_name"] = data.product_category_name.map(dictionnaire)

# %%
data["categorie_regroupee"] = data.product_category_name.apply(categorie_regroupee)

# %%
data
# Out:
#         Unnamed: 0                       customer_id  \
# 0                0  08c5351a6aca1c1589a38f244edeee9d
# 1                1  08c5351a6aca1c1589a38f244edeee9d
# 2                2  683c54fc24d40ee9f8a6fc179fd9856c
# 3                3  86dc2ffce2dfff336de2f386a786e574
# 4                4  86dc2ffce2dfff336de2f386a786e574
# ...            ...                               ...
# 112367      112367  448945bc713d98b6726e82eda6249b9e
# 112368      112368  e60df9449653a95af4549bbfcb18a6eb
# 112369      112369  448945bc713d98b6726e82eda6249b9e
# 112370      112370  448945bc713d98b6726e82eda6249b9e
# 112371      112371  4b7decb9b58e2569548b8b4c8e20e8d7
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 0       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 1       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 2       4854e9b3feff728c13ee5fc7d1547e92                     99025
# ...

# %%
data2 = data.groupby(data.customer_unique_id)

# %%
meilleur_secteur = data.groupby(data.categorie_regroupee).sum()
# Out:
# /tmp/ipykernel_9936/139646123.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meilleur_secteur = data.groupby(data.categorie_regroupee).sum()

# %%
print(type(meilleur_secteur))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
meilleur_secteur = meilleur_secteur.reset_index()

# %%
sns.barplot(x= meilleur_secteur.categorie_regroupee , y = meilleur_secteur.price_x)
plt.figure(figsize=(50,10))
plt.show()

# %%
data2.head()
# Out:
#         Unnamed: 0                       customer_id  \
# 0                0  08c5351a6aca1c1589a38f244edeee9d
# 1                1  08c5351a6aca1c1589a38f244edeee9d
# 2                2  683c54fc24d40ee9f8a6fc179fd9856c
# 3                3  86dc2ffce2dfff336de2f386a786e574
# 4                4  86dc2ffce2dfff336de2f386a786e574
# ...            ...                               ...
# 112367      112367  448945bc713d98b6726e82eda6249b9e
# 112368      112368  e60df9449653a95af4549bbfcb18a6eb
# 112369      112369  448945bc713d98b6726e82eda6249b9e
# 112370      112370  448945bc713d98b6726e82eda6249b9e
# 112371      112371  4b7decb9b58e2569548b8b4c8e20e8d7
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 0       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 1       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 2       4854e9b3feff728c13ee5fc7d1547e92                     99025
# ...

# %%
sns.set_style("whitegrid")
sns.barplot(x= meilleur_secteur.categorie_regroupee , y = meilleur_secteur.price_x)

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
meilleur_secteur2 = data.groupby(data.categorie_regroupee).mean()
# Out:
# /tmp/ipykernel_9936/1483751258.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meilleur_secteur2 = data.groupby(data.categorie_regroupee).mean()

# %%
meilleur_secteur2 = meilleur_secteur2.reset_index()

# %%
sns.set_style("whitegrid")
sns.barplot(x= meilleur_secteur2.categorie_regroupee , y = meilleur_secteur2.review_score)

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
sns.set_style("whitegrid")
sns.barplot(x= meilleur_secteur2.categorie_regroupee , y = meilleur_secteur2.score_freq)

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
sns.set_style("whitegrid")
sns.countplot(x= data.categorie_regroupee )

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
data2 = data[data["score_freq"]!=1]

# %%
data3 = data[data["score_freq"]==1]

# %%
meilleur_secteur3 = data2.groupby(data.categorie_regroupee).mean()
# Out:
# /tmp/ipykernel_9936/1995772176.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meilleur_secteur3 = data2.groupby(data.categorie_regroupee).mean()

# %%
meilleur_secteur3 = meilleur_secteur3.reset_index()

# %%
meilleur_secteur4 = data3.groupby(data.categorie_regroupee).mean()
meilleur_secteur4 = meilleur_secteur4.reset_index()
# Out:
# /tmp/ipykernel_9936/3433754523.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meilleur_secteur4 = data3.groupby(data.categorie_regroupee).mean()

# %%
sns.set_style("whitegrid")
sns.violinplot(x = data3.categorie_regroupee,y= data3.price_y)

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
sns.set_style("whitegrid")
sns.countplot(x= data2.categorie_regroupee )

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
sns.set_style("whitegrid")
sns.barplot(x= meilleur_secteur3.categorie_regroupee , y = meilleur_secteur3.score_freq)

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
sns.set_style("whitegrid")
sns.countplot(x= meilleur_secteur3.categorie_regroupee )

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
meilleur_secteur2 = data.groupby(data.categorie_regroupee).mean()
# Out:
# /tmp/ipykernel_9936/1483751258.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meilleur_secteur2 = data.groupby(data.categorie_regroupee).mean()

# %%
meanie = data.groupby(data.customer_unique_id).mean()
# Out:
# /tmp/ipykernel_9936/1210194840.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meanie = data.groupby(data.customer_unique_id).mean()

# %%
meanie
# Out:
#                                   Unnamed: 0  customer_zip_code_prefix  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2     86321.0                    7787.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f     85148.0                    6053.0
# 0000f46a3911fa3c0805444483337064      4203.0                   88115.0
# 0000f6ccb0745a6a4b88665a16c9f078     32973.0                   66812.0
# 0004aac84e0df4da2b147fca70cf8255     38724.0                   18040.0
# ...                                      ...                       ...
# fffcf5a5ff07b0908bd4e2dbc735a684     14104.5                   55250.0
# fffea47cd6d3cc0a88bd621562a9d061     47464.0                   44054.0
# ffff371b4d645b6ecea244b27531430a      1841.0                   78552.0
# ffff5962728ec6157033ef9805bacc48     83686.0                   29460.0
# ffffd2657e2aad2907e67c3e9daecbeb      9092.0                   83608.0
#
#                                   order_item_id  price_x  freight_value  \
# customer_unique_id
# ...

# %%
data
# Out:
#         Unnamed: 0                       customer_id  \
# 0                0  08c5351a6aca1c1589a38f244edeee9d
# 1                1  08c5351a6aca1c1589a38f244edeee9d
# 2                2  683c54fc24d40ee9f8a6fc179fd9856c
# 3                3  86dc2ffce2dfff336de2f386a786e574
# 4                4  86dc2ffce2dfff336de2f386a786e574
# ...            ...                               ...
# 112367      112367  448945bc713d98b6726e82eda6249b9e
# 112368      112368  e60df9449653a95af4549bbfcb18a6eb
# 112369      112369  448945bc713d98b6726e82eda6249b9e
# 112370      112370  448945bc713d98b6726e82eda6249b9e
# 112371      112371  4b7decb9b58e2569548b8b4c8e20e8d7
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 0       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 1       b7d76e111c89f7ebf14761390f0f7d17                     69309
# 2       4854e9b3feff728c13ee5fc7d1547e92                     99025
# ...

# %%
import pandas as pd

# Supposons que votre dataframe s'appelle "data"
# Séparer les colonnes numériques et non numériques
numeric_cols = data.select_dtypes(include=[np.number]).columns
non_numeric_cols = data.select_dtypes(exclude=[np.number]).columns

# Agréger les colonnes numériques en utilisant la moyenne
numeric_agg = data.groupby('customer_unique_id')[numeric_cols].mean()

# Agréger les colonnes non numériques en utilisant le mode
non_numeric_agg = data.groupby('customer_unique_id')[non_numeric_cols].agg(pd.Series.mode)

# Réunir les résultats en utilisant la méthode concat
result = pd.concat([numeric_agg, non_numeric_agg], axis=1)

# %%
non_numeric_agg2 = data.groupby('score_rfm')[non_numeric_cols].agg(pd.Series.mode)

# %%
non_numeric_agg3 = data2.groupby('score_rfm')[non_numeric_cols].agg(pd.Series.mode)

# %%
non_numeric_agg2  = non_numeric_agg2.reset_index()
sns.set_style("whitegrid")
sns.barplot(x= non_numeric_agg2.score_rfm , y = non_numeric_agg2.categorie_regroupee)

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
non_numeric_agg3  = non_numeric_agg3.reset_index()
sns.set_style("whitegrid")
sns.barplot(x= non_numeric_agg3.score_rfm , y = non_numeric_agg3.categorie_regroupee)

# Définissez la taille du graphique en pouces
figure = plt.gcf()
figure.set_size_inches(20, 6)

# Affichez le graphique
plt.show()

# %%
result
# Out:
#                                   Unnamed: 0  customer_zip_code_prefix  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2     86321.0                    7787.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f     85148.0                    6053.0
# 0000f46a3911fa3c0805444483337064      4203.0                   88115.0
# 0000f6ccb0745a6a4b88665a16c9f078     32973.0                   66812.0
# 0004aac84e0df4da2b147fca70cf8255     38724.0                   18040.0
# ...                                      ...                       ...
# fffcf5a5ff07b0908bd4e2dbc735a684     14104.5                   55250.0
# fffea47cd6d3cc0a88bd621562a9d061     47464.0                   44054.0
# ffff371b4d645b6ecea244b27531430a      1841.0                   78552.0
# ffff5962728ec6157033ef9805bacc48     83686.0                   29460.0
# ffffd2657e2aad2907e67c3e9daecbeb      9092.0                   83608.0
#
#                                   order_item_id  price_x  freight_value  \
# customer_unique_id
# ...

# %%
df_id = result

# %%
df_id.to_csv("df_par_id.csv")

# %%
df = pd.read_csv("df_par_id.csv")

# %%
df = df.reset_index()

# %%
df
# Out:
#        index                customer_unique_id  Unnamed: 0  \
# 0          0  0000366f3b9a7992bf8c76cfdf3221e2     86321.0
# 1          1  0000b849f77a49e4a4ce2b2a4ca5be3f     85148.0
# 2          2  0000f46a3911fa3c0805444483337064      4203.0
# 3          3  0000f6ccb0745a6a4b88665a16c9f078     32973.0
# 4          4  0004aac84e0df4da2b147fca70cf8255     38724.0
# ...      ...                               ...         ...
# 94716  94716  fffcf5a5ff07b0908bd4e2dbc735a684     14104.5
# 94717  94717  fffea47cd6d3cc0a88bd621562a9d061     47464.0
# 94718  94718  ffff371b4d645b6ecea244b27531430a      1841.0
# 94719  94719  ffff5962728ec6157033ef9805bacc48     83686.0
# 94720  94720  ffffd2657e2aad2907e67c3e9daecbeb      9092.0
#
#        customer_zip_code_prefix  order_item_id  price_x  freight_value  \
# 0                        7787.0            1.0   129.90          12.00
# 1                        6053.0            1.0    18.90           8.29
# ...

# %% [markdown]
# CLEANING A FAIRE

# %%
df.columns
# Out:
# Index(['index', 'customer_unique_id', 'Unnamed: 0', 'customer_zip_code_prefix',
#        'order_item_id', 'price_x', 'freight_value', 'review_score',
#        'product_name_lenght', 'product_description_lenght',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'diff_days', 'dummy',
#        'score_freq', 'price_y', 'score_rec', 'score_montant', 'score_rfm',
#        'customer_id', 'customer_unique_id.1', 'customer_city',
#        'customer_state', 'order_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'product_id', 'seller_id',
#        'shipping_limit_date', 'review_id', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp', 'product_category_name', 'date_achat',
# ...

# %%
df.describe()
# Out:
#               index     Unnamed: 0  customer_zip_code_prefix  order_item_id  \
# count  94721.000000   94721.000000              94721.000000   94721.000000
# mean   47360.000000   56456.436489              35222.593993       1.070204
# std    27343.741761   32425.344375              29822.400503       0.264691
# min        0.000000       0.500000               1003.000000       1.000000
# 25%    23680.000000   28405.000000              11410.000000       1.000000
# 50%    47360.000000   56498.000000              24445.000000       1.000000
# 75%    71040.000000   84505.000000              59067.000000       1.000000
# max    94720.000000  112366.000000              99990.000000      11.000000
#
#             price_x  freight_value  review_score  product_name_lenght  \
# count  94721.000000   94721.000000  94721.000000         93417.000000
# mean     126.334658      20.222668      4.102202            48.839110
# std      190.410031      15.816026      1.326758             9.903186
# ...

# %%
df = df[[ 'customer_unique_id', 
        'freight_value', 'review_score',
       'score_freq', 'price_y',
        'score_rec', 'score_montant', 'score_rfm', "order_purchase_timestamp",
         'customer_city',
       'order_id', 
        'product_id', 'seller_id',
        'categorie_regroupee']]

# %%
df
# Out:
#                      customer_unique_id  freight_value  review_score  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2          12.00           5.0
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f           8.29           4.0
# 2      0000f46a3911fa3c0805444483337064          17.22           3.0
# 3      0000f6ccb0745a6a4b88665a16c9f078          17.63           4.0
# 4      0004aac84e0df4da2b147fca70cf8255          16.89           5.0
# ...                                 ...            ...           ...
# 94716  fffcf5a5ff07b0908bd4e2dbc735a684         248.71           5.0
# 94717  fffea47cd6d3cc0a88bd621562a9d061          19.69           4.0
# 94718  ffff371b4d645b6ecea244b27531430a          22.56           5.0
# 94719  ffff5962728ec6157033ef9805bacc48          18.69           5.0
# 94720  ffffd2657e2aad2907e67c3e9daecbeb          14.57           5.0
#
#        score_freq  price_y  score_rec  score_montant  score_rfm  \
# 0             1.0   129.90        4.0            4.0        9.0
# ...

# %%
df.to_csv("df_par_id.csv")

# %% [markdown]
# ## MAINTENANT QUE ON A NOTRE DF , ON VA POUVOIR L'analyser

# %%
df
# Out:
#                      customer_unique_id  freight_value  review_score  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2          12.00           5.0
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f           8.29           4.0
# 2      0000f46a3911fa3c0805444483337064          17.22           3.0
# 3      0000f6ccb0745a6a4b88665a16c9f078          17.63           4.0
# 4      0004aac84e0df4da2b147fca70cf8255          16.89           5.0
# ...                                 ...            ...           ...
# 94716  fffcf5a5ff07b0908bd4e2dbc735a684         248.71           5.0
# 94717  fffea47cd6d3cc0a88bd621562a9d061          19.69           4.0
# 94718  ffff371b4d645b6ecea244b27531430a          22.56           5.0
# 94719  ffff5962728ec6157033ef9805bacc48          18.69           5.0
# 94720  ffffd2657e2aad2907e67c3e9daecbeb          14.57           5.0
#
#        score_freq  price_y  score_rec  score_montant  score_rfm  \
# 0             1.0   129.90        4.0            4.0        9.0
# ...

# %%
sns.heatmap(data.corr())
# Out:
# /tmp/ipykernel_9936/1794321463.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <AxesSubplot: >

# %%
sns.boxplot(data.price_y)
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(x = data.review_score,y = data.price_y)
# Out:
# <AxesSubplot: xlabel='review_score', ylabel='price_y'>

# %%
sns.boxplot(x = data.review_score,y = data.score_rfm)
# Out:
# <AxesSubplot: xlabel='review_score', ylabel='score_rfm'>

# %%
sns.boxplot(x = data.score_rfm,y = data.score_freq )
# Out:
# <AxesSubplot: xlabel='score_rfm', ylabel='score_freq'>
